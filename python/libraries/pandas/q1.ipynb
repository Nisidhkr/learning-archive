# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("03_FIDE_Chess_Ratings.csv")

# %%
df.head()
# Out:
#          id                            name  fed sex title wtitle otitle  foa  \
# 0  53707043                       A Darshil  IND   M   NaN    NaN    NaN  NaN
# 1  53200465  A F M Ehteshamul, Hoque (tuhin  BAN   M   NaN    NaN    NaN  NaN
# 2   5716365                 A Hamid, Harman  MAS   M   NaN    NaN    NaN  NaN
# 3  53200553                      A I Sabbir  BAN   M   NaN    NaN    NaN  NaN
# 4   5045886                   A K, Kalshyan  IND   M   NaN    NaN    NaN  NaN
#
#    rating  games   k  bday
# 0    1412      4  40  2013
# 1    1797      0  40  1977
# 2    1552      0  20  1970
# 3    1607      0  40  1995
# 4    1747      0  20  1964
